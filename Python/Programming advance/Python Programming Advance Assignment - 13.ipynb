# %% [markdown]
# # Python Programming Advance Assignment - 13

# %% [markdown]
# ### Question 1. Create a function that takes a list and string. The function should remove the letters in the string from the list, and return the list.
#
# Examples
#
# remove_letters(["s", "t", "r", "i", "n", "g", "w"], "string") ➞ ["w"]
#
# remove_letters(["b", "b", "l", "l", "g", "n", "o", "a", "w"], "balloon") ➞ ["b", "g", "w"]
#
# remove_letters(["d", "b", "t", "e", "a", "i"], "edabit") ➞ []
#
# ### Answer:

# %%
def remove_letters(lst,string):
    lst_copy = lst.copy()
    for i in string:
        if i in lst:
            lst.remove(i)
    print(f'remove_letters{lst_copy,string} ➞ {lst}')

remove_letters(["s", "t", "r", "i", "n", "g", "w"], "string")
remove_letters(["b", "b", "l", "l", "g", "n", "o", "a", "w"], "balloon")
remove_letters(["d", "b", "t", "e", "a", "i"], "edabit")
# Out:
# remove_letters(['s', 't', 'r', 'i', 'n', 'g', 'w'], 'string') ➞ ['w']
# remove_letters(['b', 'b', 'l', 'l', 'g', 'n', 'o', 'a', 'w'], 'balloon') ➞ ['b', 'g', 'w']
# remove_letters(['d', 'b', 't', 'e', 'a', 'i'], 'edabit') ➞ []

# %% [markdown]
# ### Question 2. A block sequence in three dimensions. We can write a formula for this one:
#
# ![image.png](attachment:image.png)
#
# Create a function that takes a number (step) as an argument and returns the amount of blocks in that step.
#
# Examples
#
# blocks(1) ➞ 5
#
# blocks(5) ➞ 39
#
# blocks(2) ➞ 12
#
# ### Answer:

# %%
def blocks(n):
    
    n_copy = n
    part = (n_copy*3) + (n_copy-1)
    for i in range(2,n+2):
        part = part + i
    print(f"blocks({n_copy}) ➞ {part}")
    
blocks(1)
blocks(2)
blocks(3)
blocks(4)
blocks(5)
# Out:
# blocks(1) ➞ 5
# blocks(2) ➞ 12
# blocks(3) ➞ 20
# blocks(4) ➞ 29
# blocks(5) ➞ 39

# %% [markdown]
# ### Question 3. Create a function that subtracts one positive integer from another, without using any arithmetic operators such as -, %, /, +, etc.
#
# Examples
#
# my_sub(5, 9) ➞ 4
#
# my_sub(10, 30) ➞ 20
#
# my_sub(0, 0) ➞ 0
#
# ### Answer:

# %%
#Approach 1:

def my_sub_1(x,y):
    
    from operator import sub
    output = sub(x,y) if x >= y else sub(y,x)
    print(f'my_sub{x,y} ➞ {output}')
    
my_sub_1(5, 9)
my_sub_1(10, 30)
my_sub_1(0, 0)

print()        
#Approach 2:

def my_sub_2(x,y):
    diff = []
    if x < y:
        diff = [i for i in range(x, y)]
    else:
        diff = [i for i in range(y, x)]
    output = len(diff)
    print(f"my_sub{x,y} ➞ {output}") 
    
my_sub_2(5, 9)
my_sub_2(10, 30)
my_sub_2(0,0)
# Out:
# my_sub(5, 9) ➞ 4
# my_sub(10, 30) ➞ 20
# my_sub(0, 0) ➞ 0
#
# my_sub(5, 9) ➞ 4
# my_sub(10, 30) ➞ 20
# my_sub(0, 0) ➞ 0

# %% [markdown]
# ### Question 4. Create a function that takes a string containing money in dollars and pounds sterling (seperated by comma) and returns the sum of dollar bills only, as an integer.
#
# For the input string:
#
#    - Each amount is prefixed by the currency symbol: $ for dollars and £ for pounds.
#    - Thousands are represented by the suffix k.
#
# i.e. $4k = $4,000 and £40k = £40,000
#
# Examples
#
# add_bill("d20,p40,p60,d50") ➞ 20 + 50 = 70
#
# add_bill("p30,d20,p60,d150,p360") ➞ 20  + 150 = 170
#
# add_bill("p30,d2k,p60,d200,p360") ➞ 2 * 1000 + 200 = 2200
#
# ### Answer:

# %%
def add_bill(string):
    
    currency_stock_room = string.split(",")
    dollar_stock_room = []
    
    for i in currency_stock_room:
        if i[0] == "d":
            dollar_stock_room.append(i[1:])
            
    for j in range(len(dollar_stock_room)):
        if dollar_stock_room[j].endswith("k"):
            dollar_stock_room[j] = dollar_stock_room[j].replace("k","000")

    output = sum([int(k) for k in dollar_stock_room])
    
    print(f"add_bill({string}) ➞ {output}")
    
add_bill("d20,p40,p60,d50")
add_bill("p30,d20,p60,d150,p360")
add_bill("p30,d2k,p60,d200,p360")
# Out:
# add_bill(d20,p40,p60,d50) ➞ 70
# add_bill(p30,d20,p60,d150,p360) ➞ 170
# add_bill(p30,d2k,p60,d200,p360) ➞ 2200

# %% [markdown]
# ### Question 5. Create a function that flips a horizontal list into a vertical list, and a vertical list into a horizontal list.
#
# In other words, take an 1 x n list (1 row + n columns) and flip it into a n x 1 list (n rows and 1 column), and vice versa.
#
# Examples
#
# flip_list([1, 2, 3, 4]) ➞ [[1], [2], [3], [4]]
# #### Take a horizontal list and flip it vertical.
#
# flip_list([[5], [6], [9]]) ➞ [5, 6, 9]
# #### Take a vertical list and flip it horizontal.
#
# flip_list([]) ➞ []
#
# ### Answer:

# %%
def flip_list(lst):
    if len(lst) > 0:
        output = [i[0] for i in lst] if isinstance(lst[0],list) else [[i] for i in lst]
    else:
        output = []
    print(f'flip_list({lst}) ➞ {output}')
        
flip_list([1,2,3,4]) 
flip_list([[5],[6],[9]])
flip_list([])
# Out:
# flip_list([1, 2, 3, 4]) ➞ [[1], [2], [3], [4]]
# flip_list([[5], [6], [9]]) ➞ [5, 6, 9]
# flip_list([]) ➞ []
