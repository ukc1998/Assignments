# %% [markdown]
# # Python Programming Advance Assignment - 6

# %% [markdown]
# ### Question 1. You are given two strings s and t. String t is generated by randomly shuffling string s and then adding one more letter at a random position. Return the letter that was added to t.
#
# Examples
#
# find_the_difference("abcd", "abcde") ➞ "e"
#
# find_the_difference("", "y") ➞ "y"
#
# find_the_difference("ae", "aea") ➞ "a"
#
# ### Answer:

# %%
def find_the_difference(s,t):
    
    s_list = [i for i in s]
    t_list = [i for i in t]
    
    if set(s_list) == set(t_list):
        for i in s:
            if s.count(i) < t.count(i):
                output = i
    else:
        for i in list(set(t_list)):
            if i not in list(set(s_list)):
                output = i
                
    print(f"find_the_difference{s,t} ➞ {output}")

find_the_difference("abcd", "abcde")
find_the_difference("", "y")
find_the_difference("ae", "aea")
# Out:
# find_the_difference('abcd', 'abcde') ➞ e
# find_the_difference('', 'y') ➞ y
# find_the_difference('ae', 'aea') ➞ a

# %% [markdown]
# ### Question 2. Given a function that accepts unlimited arguments, check and count how many data types are in those arguments. Finally return the total in a list.
#
# List order is:
#
# `[int, str, bool, list, tuple, dictionary]`
#
# Examples:
#
# count_datatypes(1, 45, "Hi", False) ➞ [2, 1, 1, 0, 0, 0]
#
# count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1) ➞ [3, 0, 0, 1, 1, 0]
#
# count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23) ➞ [2, 2, 3, 1, 0, 2]
#
# count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6]) ➞ [2, 0, 1, 2, 2, 0]
#
# ### Answer:

# %%
def count_datatypes(*args):
    
    from collections import OrderedDict
    
    output = OrderedDict({'int':0,'str':0,'bool':0,'list':0,'tuple':0,'dict':0})
    for i in args:
        output[type(i).__name__] += 1
    print(f'count_datatypes{args}  ➞  {list(output.values())}')
    
count_datatypes(1, 45, "Hi", False)   
count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1)
count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23)
count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6])
# Out:
# count_datatypes(1, 45, 'Hi', False)  ➞  [2, 1, 1, 0, 0, 0]
# count_datatypes([10, 20], ('t', 'Ok'), 2, 3, 1)  ➞  [3, 0, 0, 1, 1, 0]
# count_datatypes('Hello', 'Bye', True, True, False, {'1': 'One', '2': 'Two'}, [1, 3], {'Brayan': 18}, 25, 23)  ➞  [2, 2, 3, 1, 0, 2]
# count_datatypes(4, 21, ('ES', 'EN'), ('a', 'b'), False, [1, 2, 3], [4, 5, 6])  ➞  [2, 0, 1, 2, 2, 0]

# %% [markdown]
# ### Question 3. A Fibonacci string is a precedence of the Fibonacci series. It works with any two characters of the English alphabet (as opposed to the numbers 0 and 1 in the Fibonacci series) as the initial items and concatenates them together as it progresses in a similar fashion as the Fibonacci series.
#
# Examples
#
# fib_str(3, ["j", "h"]) ➞ "j, h, hj"
#
# fib_str(5, ["e", "a"]) ➞ "e, a, ae, aea, aeaae"
#
# fib_str(6, ["n", "k"]) ➞ "n, k, kn, knk, knkkn, knkknknk"
#
# ### Answer:

# %%
def fib_str(n,lst):
    
    f0,f1=lst[0],lst[1]
    output_list = lst
    if n>2:
        for i in range(3,n+1):
            f0,f1=f1,f1+f0
            output_list.append(f1)
    output_string = ",".join(output_list)
    print(f"fib_string{n,lst} ➞ {output_string}")

fib_str(3, ["j", "h"])
fib_str(5, ["e", "a"])
fib_str(6, ["n", "k"])
# Out:
# fib_string(3, ['j', 'h', 'hj']) ➞ j,h,hj
# fib_string(5, ['e', 'a', 'ae', 'aea', 'aeaae']) ➞ e,a,ae,aea,aeaae
# fib_string(6, ['n', 'k', 'kn', 'knk', 'knkkn', 'knkknknk']) ➞ n,k,kn,knk,knkkn,knkknknk

# %% [markdown]
# ### Question 4. Given an integer between 0 and 26, make a variable (self.answer). That variable would be assigned to a string in this format:
#
# "nines:your answer, threes:your answer, ones:your answer"
#
# You need to find out how many ones, threes, and nines it would at least take for the number of each to add up to the given integer when multiplied by one, three or nine (depends).
#
# Examples
#
# ones_threes_nines(10) ➞ "nines:1, threes:0, ones:1"
#
# ones_threes_nines(15) ➞ "nines:1, threes:2, ones:0"
#
# ones_threes_nines(22) ➞ "nines:2, threes:1, ones:1"
#
# ### Answer:

# %%
def ones_threes_nines(n):

    n_copy = n
    output = {'nines':0,'threes':0,'ones':0}
    if n >= 0 and n <= 26:
        while n != 0:
            if n >= 9:
                n = n - 9
                output["nines"] += 1
            elif n >= 3:
                n = n - 3
                output["threes"] += 1
            elif n >= 1:
                n = n - 1
                output["ones"] += 1
                
                
    print(f"ones_threes_nines({n_copy}) ➞ \"nines:{output['nines']}, threes:{output['threes']}, ones:{output['ones']}\"")
    
ones_threes_nines(10) 
ones_threes_nines(15)
ones_threes_nines(22)
# Out:
# ones_threes_nines(10) ➞ "nines:1, threes:0, ones:1"
# ones_threes_nines(15) ➞ "nines:1, threes:2, ones:0"
# ones_threes_nines(22) ➞ "nines:2, threes:1, ones:1"

# %% [markdown]
# ### Question 5. The Fibonacci sequence is a classic use case for recursive functions since the value of the sequence at a given index is dependent on the sum of the last two values. However, the recursion tree created by solving the Fibonacci sequence recursively can grow quite fast. Therefore it can be important to think about the implications of running a function recursively. Depending on the size of n needed and the capabilities of the system in question you might want to take a different approach.
#
# Write a non-recursive function that takes an integer n and returns the Fibonacci sequence's value at index n.
#
# Examples
#
# fib(6) ➞ 8
# #### 0 + 1 = 1, 1 + 1 = 2, 1 + 2 = 3, 2 + 3 = 5, 3 + 5 = 8
#
# fib(1) ➞ 1
#
# fib(2) ➞ 1
#
# ### Answer:

# %%
# Approach 1 

def fib_fast_one(n):
    F0 = 0
    F1 = 1
    store_room = []
    for i in range(n+1):
        store_room.append(F0)
        F0, F1 = F1, F0 + F1
    print(f'fib_fast_one({n}) ➞ {store_room[-1]}')
    
    
    
    
# Approach 2 
def fib_fast_two(n):
    F0, F1 , output = 0, 1, 1
    for i in range(n + 1):
        if i > 1:
            output = F0 + F1
            F0 = F1
            F1 = output
    print(f'fib_fast_two({n}) ➞ {output}')
    
    

    
# Approach 3
def fib_fast_three(n): 
    F0, F1 = 0,1
    for i in range(n):
        F0,F1 = F1, F0 + F1
    yield F0
    

    
    

fib_fast_one(1)
fib_fast_one(2)
fib_fast_one(6)
print() 
fib_fast_two(1)
fib_fast_two(2)
fib_fast_two(6)
print()
for i in [1,2,6]:
    for j in fib_fast_three(i):
        print(f'fib_fast_three({i}) ➞ {j}')
# Out:
# fib_fast_one(1) ➞ 1
# fib_fast_one(2) ➞ 1
# fib_fast_one(6) ➞ 8
#
# fib_fast_two(1) ➞ 1
# fib_fast_two(2) ➞ 1
# fib_fast_two(6) ➞ 8
#
# fib_fast_three(1) ➞ 1
# fib_fast_three(2) ➞ 1
# fib_fast_three(6) ➞ 8
